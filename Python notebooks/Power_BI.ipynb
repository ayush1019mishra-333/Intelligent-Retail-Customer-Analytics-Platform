# %%
import pandas as pd 
import numpy as np

df= pd.read_csv(r"C:\Users\amit6\OneDrive\Desktop\Intelligent-Retail-Customer-Analytics\Data\Processed_data\customer_feature_store.csv")
df.shape
# Out:
# (5878, 16)

# %%
customer_type = (
    df.groupby("CustomerID")["CustomerType"]
      .first()
)

df["CustomerType"] = (
    df["CustomerID"]
    .map(customer_type)
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 customer_type = (
# ----> 2     df.groupby("CustomerID")["CustomerType"]
#       3       .first()
#       4 )
#       5
#
# File c:\Users\amit6\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# ...
