# %% [markdown]
# #### We will identify customers who are likely to be high-value customers so we can target them with premium offers.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    roc_auc_score,
    RocCurveDisplay
)

import joblib

# %%
df = pd.read_csv(r"C:\Users\amit6\OneDrive\Desktop\Intelligent-Retail-Customer-Analytics\Data\Processed_data\customer_feature_store.csv")
df.head()
# Out:
#    CustomerID  Frequency  TotalQuantity   Revenue        FirstPurchase  \
# 0     12346.0         12          74285  77556.46  2009-12-14 08:34:00
# 1     12347.0          8           2967   4921.53  2010-10-31 14:20:00
# 2     12348.0          5           2714   2019.40  2010-09-27 14:59:00
# 3     12349.0          4           1624   4428.69  2010-04-29 13:20:00
# 4     12350.0          1            197    334.40  2011-02-02 16:01:00
#
#           LastPurchase  AverageUnitPrice  UniqueProducts         Country  \
# 0  2011-01-18 10:01:00          6.100000              27  United Kingdom
# 1  2011-12-07 15:52:00          2.498063             126         Iceland
# 2  2011-09-25 13:13:00          3.786275              25         Finland
# 3  2011-11-21 09:51:00          8.459657             138           Italy
# 4  2011-02-02 16:01:00          3.841176              17          Norway
#
#    CustomerTenure  Recency  AverageOrderValue  AverageQuantityPerOrder  \
# ...

# %%
median_revenue = df["Revenue"].median()

df["HighValue"] = np.where(
    df["Revenue"] > median_revenue, 1 , 0 
)

# %%
df["HighValue"].value_counts()
# Out:
# HighValue
# 1    2939
# 0    2939
# Name: count, dtype: int64

# %%
X = df.drop(
    columns=[
        "CustomerID",
        "Revenue",
        "HighValue",
        "FirstPurchase",
        "LastPurchase",
        "AverageOrderValue"
    ]
)

y = df["HighValue"]

# %%
encoder = LabelEncoder()
X["Country"] = encoder.fit_transform(X["Country"])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
rf = RandomForestClassifier(
    n_estimators=300,
    max_depth=10,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=300, n_jobs=-1,
#                        random_state=42)

# %%
y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)[:,1]

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# %%
print("="*45)

print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")

print("="*45)
# Out:
# ...
# Accuracy : 0.9396
# Precision: 0.9480
# Recall   : 0.9303
# F1 Score : 0.9391
# ...

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       588
#            1       0.95      0.93      0.94       588
#
#     accuracy                           0.94      1176
#    macro avg       0.94      0.94      0.94      1176
# weighted avg       0.94      0.94      0.94      1176

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.show()

# %%
importance = pd.DataFrame({

    "Feature": X.columns,

    "Importance": rf.feature_importances_

}).sort_values(
    by="Importance",
    ascending=False
)

print(importance)
# Out:
#                      Feature  Importance
# 1              TotalQuantity    0.373580
# 0                  Frequency    0.153921
# 3             UniqueProducts    0.135154
# 5             CustomerTenure    0.100698
# 7    AverageQuantityPerOrder    0.071357
# 2           AverageUnitPrice    0.062266
# 10  AverageDaysBetweenOrders    0.061138
# 6                    Recency    0.025277
# 8       WeekendPurchaseRatio    0.011328
# 4                    Country    0.005281
# 9                 ReturnRate    0.000000

# %%
plt.figure(figsize=(10,6))
colors = [
    '#0B3C5D',   # Navy Blue
    '#328CC1',   # Blue
    '#00A8A8',   # Teal
    '#7BC043',   # Green
    '#FDE725'    # Yellow
]

plt.barh(
    importance["Feature"],
    importance["Importance"],color = colors
)

plt.gca().invert_yaxis()

plt.title("Feature Importance")

plt.show()

# %%
joblib.dump(
    rf,
    "HighValueCustomer_RF.pkl"
)
# Out:
# ['HighValueCustomer_RF.pkl']

# %% [markdown]
# - Identify premium customers for loyalty programs.
# - Target customers with personalized offers.
# - Prioritize customer support for VIP customers.
# - Improve marketing ROI by focusing campaigns on likely high-value customers.

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred,
    cmap="Blues"
)

plt.savefig(
    "confusion_matrix.png",
    dpi=300,
    bbox_inches="tight"
)

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Probability predictions
y_prob = rf.predict_proba(X_test)[:,1]

# ROC
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,5))

plt.plot(fpr,
         tpr,
         color='#0078D4',
         lw=3,
         label=f'AUC = {roc_auc:.3f}')

plt.plot([0,1],[0,1],
         linestyle='--',
         color='gray')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - High Value Customer Model")

plt.legend(loc="lower right")

plt.grid(alpha=0.3)

plt.tight_layout()

plt.savefig("ROC_Curve.png",dpi=300)

plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import pandas as pd

# Probability predictions
y_prob = rf.predict_proba(X_test)[:,1]

# ROC values
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

roc_df = pd.DataFrame({
    "False Positive Rate": fpr,
    "True Positive Rate": tpr
})

roc_df.to_csv("roc_curve_data.csv", index=False)

print("AUC:", auc(fpr, tpr))
# Out:
# AUC: 0.9883121615993337

# %%
import numpy as np
import pandas as pd

reference = pd.DataFrame({
    "False Positive Rate": np.linspace(0,1,100),
    "Random Classifier": np.linspace(0,1,100)
})

reference.to_csv("reference_line.csv", index=False)
