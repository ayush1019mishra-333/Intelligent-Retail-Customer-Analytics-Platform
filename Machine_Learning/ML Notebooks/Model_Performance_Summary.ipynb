# %%
import pandas as pd

performance = pd.DataFrame({
    "Model":[
        "Revenue Prediction",
        "High Value Customer"
    ],
    "Algorithm":[
        "Random Forest Regressor",
        "Random Forest Classifier"
    ],
    "Primary Metric":[
        "R² Score",
        "F1 Score"
    ],
    "Value":[
        0.7633,
        0.9391
    ]
})

performance
# Out:
#                  Model                 Algorithm Primary Metric   Value
# 0   Revenue Prediction   Random Forest Regressor       R² Score  0.7633
# 1  High Value Customer  Random Forest Classifier       F1 Score  0.9391

# %%
performance.to_csv(
    "model_performance_summary.csv",
    index=False
)
